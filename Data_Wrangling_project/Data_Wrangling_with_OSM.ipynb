# %%
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET 
import pprint
import re
import csv
import codecs
import cerberus
import schema
from collections import defaultdict

SAMPLE_FILE = "sample.osm"
OSM_FILE = "boston_massachusetts.osm"
SCHEMA = schema.schema

LOWER = re.compile(r'^([a-z]|_)*$')
LOWER_COLON = re.compile(r'^([a-z]|_)*:([a-z]|_)*')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

# %% [markdown]
# ### 生成样本文件
#
# 原始数据```boston_massachusetts.osm```大小为418M。
# 当k取值45，获得样本```sample.osm```，大小为9.39M，符合样本大小要求。

# %%
k = 45 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)  
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem  # 包含yield语句,编译成生成器,生成迭代值后挂起并暂停，下次继续运行
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):  #将可遍历对象组合为索引序列
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %% [markdown]
# ### 解析文件,查看标记种类和数量

# %%
def count_tags(filename):    
    tag_data = {}   # 计数存入字典中
    for event, elem in ET.iterparse(filename, events=('start',)):
        if elem.tag in tag_data:
            tag_data[elem.tag] += 1   # 已包含该tag，计数+1
        else:
            tag_data[elem.tag] = 1    # 未包含该tag，新建键值对
        
        elem.clear()
    return tag_data

print 'sample:'
print count_tags(SAMPLE_FILE)

print 'osm_file:'
print count_tags(OSM_FILE)
# Out:
# sample:
# {'node': 43398, 'nd': 51839, 'member': 278, 'tag': 20202, 'relation': 30, 'way': 6912, 'osm': 1}
# osm_file:
# {'node': 1952868, 'nd': 2350810, 'bounds': 1, 'member': 11275, 'tag': 911457, 'osm': 1, 'way': 311064, 'relation': 1325}

# %% [markdown]
# ### 探索有多少用户作出了贡献

# %%
# 提取'uid'属性值
def get_user(element): 
    if 'uid' in element.attrib:
        return element.attrib['uid']

# 使用set()获取不重复的‘uid’
def get_unique_user(filename):
    users = set() 
    for _, element in ET.iterparse(filename):  
        if get_user(element):
            users.add(get_user(element)) 
    return users

unique_users = get_unique_user(OSM_FILE)
print 'count of unique users:', len(unique_users)
# Out:
# count of unique users: 1439

# %% [markdown]
# ### 检查‘tag'标记类型

# %%
def key_type(element, keys): 
    if element.tag == 'tag':
        for tag in element.iter('tag'):
            if LOWER.search(tag.attrib['k']):
                keys['lower'] += 1
            elif LOWER_COLON.search(tag.attrib['k']):
                keys['lower_colon'] += 1
            elif PROBLEMCHARS.search(tag.attrib['k']):
                keys['problemchars'] += 1
            else:
                keys['other'] += 1 
    return keys

def check_key_type(filename):
    keys = {'lower': 0, 'lower_colon': 0, 'problemchars': 0, 'other': 0}
    open_file = open(filename, 'r')
    for _, element in ET.iterparse(open_file,events=('start', )):
        keys = key_type(element, keys)
    open_file.close()
    return keys

#sample_keys = check_key_type(SAMPLE_FILE)
#print sample_keys
osm_keys = check_key_type(OSM_FILE)
print 'osm_keys', osm_keys
# Out:
# osm_keys {'problemchars': 3, 'lower': 796417, 'other': 478, 'lower_colon': 114559}

# %% [markdown]
# ### 检查'tag'标记的属性

# %%
def check_type_keys(filename, type_re):
    type_keys = {}
    open_file = open(filename, 'r')
    for _, element in ET.iterparse(open_file,events=('start', )):
        if element.tag == 'tag':
            for tag in element.iter('tag'):
                if type_re.search(tag.attrib['k']):
                    if tag.attrib['k'] in type_keys:
                        type_keys[tag.attrib['k']] += 1
                    else:
                        type_keys[tag.attrib['k']] = 1
    open_file.close()
    return type_keys

# %% [markdown]
# #### 对含有冒号":"的key分类计数

# %%
# 含有冒号":"的key
osm_lower_colon_keys = check_type_keys(OSM_FILE, LOWER_COLON)
osm_lower_colon_keys
# Out:
# {'abandoned:railway': 2,
#  'access:conditional': 1,
#  'access:employee': 51,
#  'addr:city': 3436,
#  'addr:city_parent': 7,
#  'addr:country': 133,
#  'addr:county': 7,
#  'addr:description': 1,
#  'addr:floor': 1,
#  'addr:full': 2,
#  'addr:housename': 149,
#  'addr:housenumber': 7894,
#  'addr:inclusion': 35,
#  'addr:interpolation': 47,
#  'addr:neighbourhood': 6,
#  'addr:place': 5,
#  'addr:postcode': 2760,
#  'addr:state': 2513,
#  'addr:street': 6545,
#  'addr:street_1': 1,
#  'addr:unit': 9,
#  'aerodrome:type': 1,
#  'alt_name:ru': 1,
#  'alt_name:vi': 1,
#  'amenity:1997-2015': 1,
#  'area:highway': 52,
#  'bicycle:oneway': 1,
#  'bridge:material': 1,
#  'bridge:movable': 2,
#  'bridge:name': 4,
#  'bridge:structure': 3,
#  'bridge:structure:beam': 1,
#  'bridge:support': 11,
#  'building:architecture': 2,
#  'building:colour': 627,
#  'building:height': 419,
#  'building:levels': 3097,
#  'building:material': 1025,
#  'building:min_level': 124,
#  'building:name': 1,
#  'building:part': 1711,
#  'building:roof:colour': 3,
#  'building:roof:shape': 4,
#  'building:trees': 1,
#  'building:use': 2,
#  'building:yard': 1,
#  'building_entrance:steps': 1,
#  'camera:direction': 71,
#  'camera:features': 25,
#  'camera:mount': 151,
#  'camera:type': 65,
#  'capacity:disabled': 16,
#  'census:population': 15,
#  'change_date:first': 15,
#  'change_date:fourth': 4,
#  'change_date:second': 15,
#  'change_date:third': 4,
#  'communication:mobile_phone': 4,
#  'community:en': 2,
#  'community:gender': 4,
#  'construction:amenity': 1,
#  'construction:highway': 4,
#  'contact:email': 43,
#  'contact:facebook': 2,
#  'contact:fax': 15,
#  'contact:foursquare': 1,
#  'contact:github': 1,
#  'contact:google_plus': 1,
#  'contact:phone': 70,
#  'contact:tty': 1,
#  'contact:twitter': 1,
#  'contact:webcam': 25,
#  'contact:website': 70,
#  'contact:yelp': 1,
#  'cost:coffee': 12,
#  'crossing:barrier': 6,
#  'currency:USD': 10,
#  'currency:others': 8,
#  'cycleway:left': 57,
#  'cycleway:right': 480,
#  'cycleway:right:buffer': 16,
#  'demolished:amenity': 1,
#  'demolished:building': 3,
#  'demolished:ele': 1,
#  'demolished:name': 1,
#  'description:en': 2,
#  'design:incomplete': 13,
#  'destination:ref': 23,
#  'destination:ref:to': 1,
#  'diet:vegan': 3,
#  'diet:vegetarian': 4,
#  'disused:amenity': 3,
#  'disused:railway': 2,
#  'disused:shop': 4,
#  'fire_hydrant:position': 41,
#  'fire_hydrant:type': 88,
#  'fire_hydrant:water_source': 8,
#  'flag:type': 7,
#  'former:name': 1,
#  'fuel:diesel': 1,
#  'fuel:octane_95': 1,
#  'generator:method': 4,
#  'generator:output:electricity': 8,
#  'generator:output:hot_water': 1,
#  'generator:output:steam': 1,
#  'generator:source': 15,
#  'generator:type': 4,
#  'gnis:Class': 143,
#  'gnis:County': 143,
#  'gnis:County_num': 143,
#  'gnis:ST_alpha': 143,
#  'gnis:ST_num': 143,
#  'gnis:county': 3,
#  'gnis:county_id': 1125,
#  'gnis:county_nam': 1,
#  'gnis:county_name': 820,
#  'gnis:created': 1160,
#  'gnis:feature': 1,
#  'gnis:feature_id': 2115,
#  'gnis:feature_type': 37,
#  'gnis:id': 146,
#  'gnis:import_uuid': 775,
#  'gnis:reviewed': 742,
#  'gnis:state': 1,
#  'gnis:state_id': 1125,
#  'headway:peak': 1,
#  'healthcare:speciality': 13,
#  'healthcare:speciality:ophthalmology': 1,
#  'healthcare:speciality:otolaryngology': 1,
#  'heritage:operator': 5,
#  'historic:highway': 1,
#  'historic:natural': 1,
#  'historic:railway': 8,
#  'historical:shop': 1,
#  'internet_access:fee': 32,
#  'internet_access:ssid': 7,
#  'is_in:continent': 2,
#  'is_in:country': 2,
#  'is_in:country_code': 1,
#  'is_in:state': 13,
#  'isced:level': 3,
#  'junction:ref': 7,
#  'lanes:backward': 581,
#  'lanes:both_ways': 1,
#  'lanes:forward': 594,
#  'massgis:ALT_SITE_N': 8,
#  'massgis:ARTICLE97': 1289,
#  'massgis:ASSESS_ACR': 1290,
#  'massgis:ASSESS_BLK': 131,
#  'massgis:ASSESS_LOT': 233,
#  'massgis:ASSESS_MAP': 242,
#  'massgis:ASSESS_SUB': 19,
#  'massgis:ATT_DATE': 1290,
#  'massgis:BASE_MAP': 141,
#  'massgis:BOND_ACCT': 2,
#  'massgis:CAL_DATE_R': 102,
#  'massgis:COMMENTS': 539,
#  'massgis:DCAM_ID': 1291,
#  'massgis:DEED_ACRES': 1292,
#  'massgis:EOEAINVOLV': 1290,
#  'massgis:FEESYM': 1292,
#  'massgis:FEE_OWNER': 1292,
#  'massgis:FY_FUNDING': 1291,
#  'massgis:GRANTPROG1': 217,
#  'massgis:GRANTPROG2': 18,
#  'massgis:GRANTTYPE1': 217,
#  'massgis:GRANTTYPE2': 18,
#  'massgis:INTSYM': 45,
#  'massgis:IT_VALC': 667,
#  'massgis:IT_VALDESC': 668,
#  'massgis:LEV_PROT': 1292,
#  'massgis:LOC_ID': 5,
#  'massgis:MANAGER': 667,
#  'massgis:MANAGR_ABR': 653,
#  'massgis:MANAGR_TYP': 664,
#  'massgis:OBJECTID': 667,
#  'massgis:OLI_1_ABRV': 45,
#  'massgis:OLI_1_INT': 45,
#  'massgis:OLI_1_ORG': 45,
#  'massgis:OLI_1_TYPE': 45,
#  'massgis:OLI_2_ABRV': 2,
#  'massgis:OLI_2_INT': 3,
#  'massgis:OLI_2_ORG': 3,
#  'massgis:OLI_2_TYPE': 3,
#  'massgis:OS_DEED_BO': 1291,
#  'massgis:OS_DEED_PA': 1291,
#  'massgis:OS_ID': 1289,
#  'massgis:OWNER_ABRV': 1186,
#  'massgis:OWNER_TYPE': 1292,
#  'massgis:PALIS_ID': 670,
#  'massgis:POLY_CODE': 667,
#  'massgis:POLY_ID': 1290,
#  'massgis:PRIM_PURP': 1292,
#  'massgis:PROJ_ID1': 486,
#  'massgis:PROJ_ID2': 65,
#  'massgis:PROJ_ID3': 15,
#  'massgis:PUB_ACCESS': 1292,
#  'massgis:SITE_NAME': 1230,
#  'massgis:SOURCE': 667,
#  'massgis:SOURCE_MAP': 617,
#  'massgis:SOURCE_SCA': 667,
#  'massgis:SOURCE_TYP': 87,
#  'massgis:TOWN_ID': 1293,
#  'massgis:WETCODE': 667,
#  'massgis:geom_id': 391,
#  'massgis:id': 29,
#  'massgis:ref': 1223,
#  'massgis:school_id': 288,
#  'massgis:way_id': 24464,
#  'maxspeed:advisory': 1,
#  'maxspeed:variable': 4,
#  'monastery:type': 2,
#  'monitoring:bicycle': 1,
#  'name:1997-2015': 1,
#  'name:ab': 1,
#  'name:ace': 1,
#  'name:af': 1,
#  'name:als': 1,
#  'name:am': 1,
#  'name:an': 1,
#  'name:ang': 1,
#  'name:ar': 6,
#  'name:arc': 1,
#  'name:arz': 1,
#  'name:as': 1,
#  'name:ast': 1,
#  'name:av': 1,
#  'name:ay': 1,
#  'name:az': 3,
#  'name:ba': 2,
#  'name:bar': 1,
#  'name:bat-smg': 1,
#  'name:bcl': 1,
#  'name:be': 3,
#  'name:be-tarask': 1,
#  'name:bg': 4,
#  'name:bi': 1,
#  'name:bm': 1,
#  'name:bn': 2,
#  'name:bo': 1,
#  'name:bpy': 1,
#  'name:br': 2,
#  'name:bs': 1,
#  'name:bxr': 1,
#  'name:ca': 2,
#  'name:cbk-zam': 1,
#  'name:cdo': 1,
#  'name:ce': 1,
#  'name:ceb': 1,
#  'name:chr': 1,
#  'name:chy': 1,
#  'name:ckb': 1,
#  'name:co': 1,
#  'name:crh': 1,
#  'name:cs': 2,
#  'name:csb': 1,
#  'name:cu': 1,
#  'name:cv': 2,
#  'name:cy': 2,
#  'name:da': 2,
#  'name:de': 4,
#  'name:diq': 1,
#  'name:dsb': 1,
#  'name:dv': 1,
#  'name:dz': 1,
#  'name:ee': 1,
#  'name:el': 4,
#  'name:eml': 1,
#  'name:en': 85,
#  'name:eo': 4,
#  'name:es': 7,
#  'name:et': 3,
#  'name:etymology:wikidata': 1,
#  'name:eu': 3,
#  'name:ext': 1,
#  'name:fa': 3,
#  'name:ff': 1,
#  'name:fi': 2,
#  'name:fiu-vro': 1,
#  'name:fo': 1,
#  'name:fr': 7,
#  'name:frp': 1,
#  'name:frr': 1,
#  'name:fur': 1,
#  'name:fy': 1,
#  'name:ga': 2,
#  'name:gag': 1,
#  'name:gan': 1,
#  'name:gd': 2,
#  'name:gl': 2,
#  'name:glk': 1,
#  'name:gn': 1,
#  'name:gu': 1,
#  'name:gv': 1,
#  'name:ha': 1,
#  'name:hak': 1,
#  'name:haw': 2,
#  'name:he': 7,
#  'name:hi': 3,
#  'name:hif': 1,
#  'name:hr': 2,
#  'name:hsb': 1,
#  'name:ht': 1,
#  'name:hu': 2,
#  'name:hy': 3,
#  'name:ia': 1,
#  'name:id': 2,
#  'name:ie': 1,
#  'name:ig': 1,
#  'name:ik': 1,
#  'name:ilo': 1,
#  'name:io': 1,
#  'name:is': 2,
#  'name:it': 3,
#  'name:iu': 1,
#  'name:ja': 6,
#  'name:jbo': 1,
#  'name:jv': 2,
#  'name:ka': 3,
#  'name:kaa': 1,
#  'name:kab': 1,
#  'name:kbd': 1,
#  'name:ki': 1,
#  'name:kk': 2,
#  'name:kl': 1,
#  'name:km': 1,
#  'name:kn': 2,
#  'name:ko': 5,
#  'name:koi': 1,
#  'name:krc': 1,
#  'name:ks': 1,
#  'name:ksh': 1,
#  'name:ku': 2,
#  'name:kv': 1,
#  'name:kw': 1,
#  'name:ky': 1,
#  'name:la': 2,
#  'name:lad': 1,
#  'name:lb': 2,
#  'name:lbe': 1,
#  'name:lez': 1,
#  'name:lg': 1,
#  'name:li': 1,
#  'name:lij': 1,
#  'name:lmo': 1,
#  'name:ln': 1,
#  'name:lo': 1,
#  'name:lt': 4,
#  'name:ltg': 1,
#  'name:lv': 4,
#  'name:map-bms': 1,
#  'name:mdf': 1,
#  'name:mg': 1,
#  'name:mhr': 1,
#  'name:mi': 1,
#  'name:min': 1,
#  'name:mk': 2,
#  'name:ml': 1,
#  'name:mn': 1,
#  'name:mr': 2,
#  'name:mrj': 1,
#  'name:ms': 2,
#  'name:mt': 1,
#  'name:mwl': 1,
#  'name:my': 2,
#  'name:myv': 1,
#  'name:mzn': 1,
#  'name:na': 1,
#  'name:nah': 1,
#  'name:nap': 1,
#  'name:nds': 1,
#  'name:nds-nl': 1,
#  'name:ne': 1,
#  'name:new': 1,
#  'name:nl': 2,
#  'name:nn': 1,
#  'name:no': 1,
#  'name:nov': 1,
#  'name:nrm': 1,
#  'name:nso': 1,
#  'name:nv': 2,
#  'name:oc': 2,
#  'name:om': 1,
#  'name:or': 1,
#  'name:original': 15,
#  'name:os': 1,
#  'name:pa': 1,
#  'name:pag': 1,
#  'name:pam': 1,
#  'name:pap': 1,
#  'name:pcd': 1,
#  'name:pdc': 1,
#  'name:pfl': 1,
#  'name:pih': 1,
#  'name:pl': 5,
#  'name:pms': 1,
#  'name:pnb': 1,
#  'name:ps': 1,
#  'name:pt': 2,
#  'name:qu': 2,
#  'name:rm': 1,
#  'name:rn': 1,
#  'name:ro': 4,
#  'name:roa-tara': 1,
#  'name:ru': 6,
#  'name:rue': 1,
#  'name:rw': 1,
#  'name:sa': 2,
#  'name:sah': 1,
#  'name:sc': 1,
#  'name:scn': 1,
#  'name:sco': 1,
#  'name:sd': 1,
#  'name:se': 1,
#  'name:sg': 1,
#  'name:sh': 1,
#  'name:si': 1,
#  'name:sk': 1,
#  'name:sl': 2,
#  'name:sm': 1,
#  'name:sn': 1,
#  'name:so': 1,
#  'name:sq': 2,
#  'name:sr': 3,
#  'name:srn': 1,
#  'name:ss': 1,
#  'name:stq': 1,
#  'name:su': 1,
#  'name:sv': 1,
#  'name:sw': 2,
#  'name:szl': 1,
#  'name:ta': 5,
#  'name:te': 2,
#  'name:tet': 1,
#  'name:tg': 1,
#  'name:th': 3,
#  'name:tk': 1,
#  'name:tl': 1,
#  'name:tn': 1,
#  'name:to': 1,
#  'name:tpi': 1,
#  'name:tr': 2,
#  'name:ts': 1,
#  'name:tt': 2,
#  'name:tw': 1,
#  'name:ty': 1,
#  'name:tzl': 1,
#  'name:udm': 1,
#  'name:ug': 2,
#  'name:uk': 9,
#  'name:ur': 2,
#  'name:uz': 1,
#  'name:vec': 1,
#  'name:vep': 1,
#  'name:vi': 2,
#  'name:vls': 1,
#  'name:vo': 1,
#  'name:wa': 1,
#  'name:war': 1,
#  'name:wo': 1,
#  'name:wuu': 1,
#  'name:xal': 1,
#  'name:xh': 1,
#  'name:xmf': 1,
#  'name:yi': 3,
#  'name:yo': 2,
#  'name:za': 1,
#  'name:zea': 1,
#  'name:zh': 6,
#  'name:zh-classical': 1,
#  'name:zh-min-nan': 1,
#  'name:zh-yue': 1,
#  'name:zu': 1,
#  'nist:fips_code': 5,
#  'nist:state_fips': 5,
#  'note:en': 20,
#  'note:lanes': 59,
#  'note:old_railway_operator': 95,
#  'note:source': 9,
#  'official_name:eo': 1,
#  'official_name:vi': 1,
#  'old_gnis:feature_id': 1,
#  'old_name:1970': 187,
#  'old_name:ru': 1,
#  'old_name:vi': 1,
#  'old_short_name:ru': 1,
#  'oneway:bicycle': 4,
#  'oneway:bus': 5,
#  'oneway:conditional': 4,
#  'operator:fourth': 4,
#  'operator:freight': 15,
#  'operator:original': 15,
#  'operator:passenger': 15,
#  'operator:second': 15,
#  'operator:third': 4,
#  'other_massgis:school_id': 1,
#  'outcrop:rock_name': 2,
#  'outcrop:rock_type': 2,
#  'parking:condition:both': 7,
#  'parking:condition:both:customers': 1,
#  'parking:condition:both:maxstay': 15,
#  'parking:condition:both:time_interval': 16,
#  'parking:condition:left': 4,
#  'parking:condition:left:maxstay': 10,
#  'parking:condition:left:time_interval': 10,
#  'parking:condition:right': 7,
#  'parking:condition:right:maxstay': 16,
#  'parking:condition:right:time_interval': 15,
#  'parking:lane': 5,
#  'parking:lane:both': 214,
#  'parking:lane:both_1': 5,
#  'parking:lane:left': 91,
#  'parking:lane:right': 98,
#  'parking:right:both': 1,
#  'parking:time:bothside': 1,
#  'payment:american_express': 9,
#  'payment:bitcoin': 16,
#  'payment:cash': 375,
#  'payment:cheque': 359,
#  'payment:coins': 14,
#  'payment:credit_cards': 2,
#  'payment:debit_cards': 2,
#  'payment:diners_club': 4,
#  'payment:discover': 2,
#  'payment:discover_card': 16,
#  'payment:electronic_purses': 1,
#  'payment:jcb': 5,
#  'payment:levelup': 2,
#  'payment:litecoin': 1,
#  'payment:mastercard': 28,
#  'payment:notes': 11,
#  'payment:other': 3,
#  'payment:visa': 29,
#  'plant:method': 1,
#  'plant:output:electricity': 1,
#  'plant:source': 1,
#  'proposed:amenity': 1,
#  'public_transport:version': 9,
#  'railway:bidirectional': 15,
#  'railway:local_operated': 2,
#  'railway:signal:direction': 4,
#  'railway:signal:main': 3,
#  'railway:signal:position': 4,
#  'railway:signal:speed_limit': 3,
#  'railway:signal:speed_limit:speed': 3,
#  'railway:switch': 2,
#  'railway:switch:configuration': 2,
#  'railway:switch:movable_frog': 2,
#  'railway:traffic_mode': 60,
#  'railway:turnout_side': 2,
#  'ramp:wheelchair': 2,
#  'recycling:cans': 7,
#  'recycling:clothes': 2,
#  'recycling:glass': 4,
#  'recycling:glass_bottles': 1,
#  'recycling:paper': 3,
#  'recycling:shoes': 1,
#  'ref:Amtrak': 1,
#  'ref:fips': 1,
#  'ref:isil': 1,
#  'ref:left': 6,
#  'ref:nrhp': 10,
#  'ref:right': 4,
#  'restriction:conditional': 11,
#  'roof:colour': 513,
#  'roof:edge': 67,
#  'roof:height': 257,
#  'roof:levels': 241,
#  'roof:material': 918,
#  'roof:orientation': 79,
#  'roof:ridge': 20,
#  'roof:shape': 1163,
#  'roof:slope:direction': 187,
#  'seamark:beacon_lateral:category': 1,
#  'seamark:beacon_lateral:colour': 1,
#  'seamark:beacon_lateral:shape': 1,
#  'seamark:beacon_lateral:system': 1,
#  'seamark:buoy_lateral:category': 5,
#  'seamark:buoy_lateral:colour': 5,
#  'seamark:buoy_lateral:shape': 5,
#  'seamark:buoy_lateral:system': 5,
#  'seamark:mooring:category': 41,
#  'seamark:restricted_area:category': 1,
#  'seamark:type': 49,
#  'service:bicycle:Bicycle_Sales_and_Service': 1,
#  'service:bicycle:chain_tool': 22,
#  'service:bicycle:diy': 10,
#  'service:bicycle:pump': 25,
#  'service:bicycle:rental': 9,
#  'service:bicycle:repair': 15,
#  'service:bicycle:retail': 18,
#  'service:bicycle:second_hand': 6,
#  'ship:type': 3,
#  'short_name:ru': 1,
#  'short_name:vi': 1,
#  'social_facility:for': 3,
#  'source:3D': 1,
#  'source:addr': 22,
#  'source:date': 1,
#  'source:geometry': 1,
#  'source:height': 1,
#  'source:hgv': 574,
#  'source:maxspeed': 607,
#  'source:name': 7,
#  'source:noname': 1,
#  'source:old_name:1970': 187,
#  'source:oneway': 4,
#  'source:pkey': 12,
#  'source:population': 6,
#  'source:position': 1,
#  'source:surface': 1,
#  'source:url': 107,
#  'source:website': 135,
#  'source_ref:addr': 1,
#  'species:en': 8,
#  'subject:wikidata': 1,
#  'surface:colour': 1,
#  'surveillance:type': 205,
#  'surveillance:zone': 83,
#  'survey:date': 1,
#  'tiger:county': 1,
#  'toilets:access': 10,
#  'toilets:disposal': 2,
#  'toilets:female': 1,
#  'toilets:male': 1,
#  'toilets:wheelchair': 25,
#  'tower:construction': 1,
#  'tower:type': 20,
#  'townhall:type': 1,
#  'traffic_sign:backward': 3,
#  'traffic_sign:forward': 3,
#  'traffic_signals:sound': 9,
#  'turn:lanes': 756,
#  'turn:lanes:backward': 263,
#  'turn:lanes:both_ways': 1,
#  'turn:lanes:forward': 258,
#  'was:amenity': 3,
#  'website:searchstring': 1,
#  'wetap:credit': 1,
#  'wetap:status': 1,
#  'wheelchair:description': 6,
#  'whitewater:grade': 5,
#  'width:feet': 25}

# %% [markdown]
# #### 对异常标签的key分类计数

# %%
# 查看匹配为problemchars的key
osm_problemchars_keys = check_type_keys(OSM_FILE, PROBLEMCHARS)
osm_problemchars_keys
# Out:
# {'(new tag)': 2, 'service area': 1}

# %% [markdown]
# #### 提取感兴趣标签的key及value

# %%
# 从文件中获取目标key及value
def get_key_value(filename, target_keys):
    all_targets = defaultdict(set)
    open_file = open(filename, 'r')
    for _, element in ET.iterparse(open_file,events=('start', )):
        if element.tag == 'tag':
            for tag in element.iter('tag'):
                if tag.attrib['k'] in target_keys:
                    all_targets[tag.attrib['k']].add(tag.attrib['v']) 
                    
    open_file.close()
    return all_targets

# %%
# 从源文件中提取所有感兴趣的key，再分别查看是否有问题
target_keys = ['addr:postcode', 'addr:state', 'addr:street', 'addr:street_1',
               'addr:unit', '(new tag)', 'service area']
all_target_keys = get_key_value(OSM_FILE, target_keys)
# Out:
# defaultdict(<type 'set'>, {'addr:unit': set(['A', 'Suite 8', '1425', '610', 'BO4', '3', '2', '1400']), 'addr:postcode': set(['02186', '02184', '02134-1327', '02189', '02134-1322', '02134-1321', '02138-1901', '02132-3226', '01821', '02134-1433', '02108', '02109', '02476', '02474', '02472', '02139', '02134-1319', 'MA 02135', '02478', '02136-2460', '02131-3025', '02136', '02140-1340', '02134', '02205', '02132', '02131', '02130', '01854', '02110-1301', '02138', '02138-2903', '02138-2901', '02134-1442', '01250', '02132-1239', '02445-7638', '02446', '02445', '02138-2742', '02120', '02121', '02210', '02124', '02125', '02126', '02215', '02128', '02129', '02474-8735', '01240', '20052', '02114-3203', '02458', '02459', 'MA 02118', 'MA 02116', '01125', '02026', 'MA 02186', '02155', 'MA', '02150', '02152', '02159', '02026-5036', '01238', '02138-2724', '02445-5841', '02138-2933', '02144', '02145', '02142', '02143', '02140', '02141', '02148', '02149', '02138-2735', '02138-2736', '02131-4931', '02118', '02138-3824', '02134-1316', '02134-1317', '02134-1312', '02134-1313', '02134-1311', '02151', '02134-1318', '01944', '02171', '02134-1409', '02174', '01754', '02170', '02122', '02138-2706', '02138-2701', '02140-2215', '02134-1420', '02127', '02114', '02134-1305', '02134-1307', '02134-1306', '02043', '02492', '02169', '02130-4803', '02191', '02190', '02199', '02138-2801', '02284-6028', '02119', '02201', '02138-3003', '02111', '02110', '02113', '02115', '02135', '02116', '02467', '02138-2762', '02138-2763']), 'addr:state': set(['ma', 'WA', 'MA- MASSACHUSETTS', 'MASSACHUSETTS', 'Ma', 'MA', 'Massachusetts']), 'addr:street_1': set(['Railroad Street']), '(new tag)': set(['Pine Avenue']), 'service area': set(['20 miles']), 'addr:street': set(['South Street', 'Brentwood St', 'Harbor Shore Drive', 'Charles Street', 'Medford St', 'Wendell Street', 'Abby Rd', 'Prichard Avenue', 'Ware Street', 'American Legion HIghway', 'Saint James Avenue', 'Dartmouth ', 'Coddington Street', 'Black Falcon Avenue', 'Savin Hill Avenue', 'Legacy Place', 'Park Place', 'Richardson Street', 'Fan Pier Boulevard', 'Sedgwick Street', 'High Street', 'McBride Street', 'Edgerly Road', 'Windsor Street', 'Gordon Road', 'Dolphin Road', 'John Street', 'Herrick Road', "Saint Mary's St.", 'Mystic Valley Parkway', 'Canton Avenue', 'Thomas Street', 'Pinckney Street', 'Winnisimmet Street', 'Farnsworth Street', 'Holyoke Street', 'PO Box 846028', 'Burroughs Street', 'First Street', 'West Second Street', 'Hillside Place', 'Central Street', 'Squantum Street', 'School Street', 'Austin Park', 'Davis Square', 'Unquity Road', 'Wormwood Street', 'Parmenter Street', 'New Rutherford Avenue', 'Putnam Avenue', 'Acorn Park', 'South Station, near Track 6', 'Professors Row', 'Leighton St', 'Renfrew Street', 'Riley Way', 'Carolina Place', 'Edge HIll Road', 'Windsor', 'Soldiers Field Road', 'Blossom Street', 'SYCAMORE ST ', 'Massachussetts Avenue', 'Tyler Street', 'Blue Hill Avenue', 'Outlook Road', 'Belgrade Avenue', 'Canal Park', 'Cottage Street', 'Essex Road', 'Bedford Street', 'Western Avenue', 'Linwood Street', 'Boston Medical Center Place', 'Amory Street', 'Courthouse Way', 'Northshore Road', 'Marlborough Street', 'Park Street Court', 'Anson Street', 'Trapelo Road', 'Wareham Street', 'Corey rd.', 'Humboldt Avenue', 'Bay State Road', 'Mildred Avenue', 'William T. Morrissey Boulevard', 'Burnside Avenue', 'Park Plaza', 'George P Hassett Drive', 'Stewart St', 'Wellington Street', 'Windom Street', 'Assembly Row', 'Boston street', 'Faneuil Hall Market', 'Holyoke Place', 'Bagnal St', 'Sunnyside Avenue', 'Shattuck Street', 'Medford Street', 'Exeter Street', 'East Dedham Street', 'Boston Avenue', 'Causeway Street', 'Bartlett Square', 'Lansdowne Street', 'Cambridge Center', 'Harborside Dr', 'Alton Street', 'Pond Avenue', 'Dana Road', 'Clinton Street', 'Percy Place', 'Friend Street', 'Willow Avenue', 'Atherton Street', 'University Road', 'Morton Street', 'Jamaica Street', 'Ashford Street', 'Oakland Rd', 'Mount Aubur ...

# %% [markdown]
# #### 依次查看感兴趣的key和value

# %%
print 'service area:', all_target_keys['service area']
# Out:
# service area: set(['20 miles'])

# %% [markdown]
# ===> key值```service area```可修正为```service_area```。

# %%
print '(new tag):', all_target_keys['(new tag)']
# Out:
# (new tag): set(['Pine Avenue'])

# %% [markdown]
# ===> key值```(new tag)```可修正为```new_tag```。

# %%
print 'addr:unit:', all_target_keys['addr:unit']
# Out:
# addr:unit: set(['A', 'Suite 8', '1425', '610', 'BO4', '3', '2', '1400'])

# %% [markdown]
# ===> key值```addr:unit```无需修正。

# %%
print 'addr:street_1:', all_target_keys['addr:street_1']
# Out:
# addr:street_1: set(['Railroad Street'])

# %% [markdown]
# ===> key值```addr:street_1```可修正为```addr:street```。

# %%
print 'postcode'
pprint.pprint(all_target_keys['addr:postcode'])
# Out:
# postcode
# set(['01125',
#      '01238',
#      '01240',
#      '01250',
#      '01754',
#      '01821',
#      '01854',
#      '01944',
#      '02026',
#      '02026-5036',
#      '02043',
#      '02108',
#      '02109',
#      '02110',
#      '02110-1301',
#      '02111',
#      '02113',
#      '02114',
#      '02114-3203',
#      '02115',
#      '02116',
#      '02118',
#      '02119',
#      '02120',
#      '02121',
#      '02122',
#      '02124',
#      '02125',
#      '02126',
#      '02127',
#      '02128',
#      '02129',
#      '02130',
#      '02130-4803',
#      '02131',
#      '02131-3025',
#      '02131-4931',
#      '02132',
#      '02132-1239',
#      '02132-3226',
#      '02134',
#      '02134-1305',
#      '02134-1306',
#      '02134-1307',
#      '02134-1311',
#      '02134-1312',
#      '02134-1313',
#      '02134-1316',
#      '02134-1317',
#      '02134-1318',
#      '02134-1319',
#      '02134-1321',
#      '02134-1322',
#      '02134-1327',
#      '02134-1409',
#      '02134-1420',
#      '02134-1433',
#      '02134-1442',
#      '02135',
#      '02136',
#      '02136-2460',
#      '02138',
#      '02138-1901',
#      '02138-2701',
#      '02138-2706',
#      '02138-2724',
#      '02138-2735',
#      '02138-2736',
#      '02138-2742',
#      '02138-2762',
#      '02138-2763',
#      '02138-2801',
#      '02138-2901',
#      '02138-2903',
#      '02138-2933',
#      '02138-3003',
#      '02138-3824',
#      '02139',
#      '02140',
#      '02140-1340',
#      '02140-2215',
#      '02141',
#      '02142',
#      '02143',
#      '02144',
#      '02145',
#      '02148',
#      '02149',
#      '02150',
#      '02151',
#      '02152',
#      '02155',
#      '02159',
#      '02169',
#      '02170',
#      '02171',
#      '02174',
#      '02184',
#      '02186',
#      '02189',
#      '02190',
#      '02191',
#      '02199',
#      '02201',
#      '02205',
#      '02210',
#      '02215',
#      '02284-6028',
#      '02445',
#      '02445-5841',
#      '02445-7638',
#      '02446',
#      '02458',
#      '02459',
#      '02467',
#      '02472',
#      '02474',
#      '02474-8735',
#      '02476',
#      '02478',
#      '02492',
#      '20052',
#      'MA',
#      'MA 02116',
#      'MA 02118',
#      'MA 02135',
#      'MA 02186'])

# %% [markdown]
# ===> key值```addr:postcode```无需修正。

# %%
print 'addr:state:', all_target_keys['addr:state']
# Out:
# addr:state: set(['ma', 'WA', 'MA- MASSACHUSETTS', 'MASSACHUSETTS', 'Ma', 'MA', 'Massachusetts'])

# %% [markdown]
# ===> key值```addr:state```的value值需要进行修正。

# %%
# 检查addr:street的值规范问题
streets = all_target_keys['addr:street']
street_entry = defaultdict(list)
for street in streets:
    street_end = street.split(" ")[-1]
    street_entry[street_end].append(street)
street_entry
# Out:
# defaultdict(list,
#             {'': ['Dartmouth ', 'SYCAMORE ST '],
#              '#12': ['Harvard St #12'],
#              '#1302': ['Cambridge Street #1302'],
#              '#501': ['Bromfield Street #501'],
#              '104': ['Mill Street, Suite 104'],
#              '1100': ['First Street, Suite 1100'],
#              '1702': ['Franklin Street, Suite 1702'],
#              '3': ['Kendall Square - 3'],
#              '303': ['First Street, Suite 303'],
#              '6': ['South Station, near Track 6'],
#              '846028': ['PO Box 846028'],
#              'Albany': ['Albany'],
#              'Artery': ['Southern Artery'],
#              'Ave': ['Highland Ave',
#               'Morrison Ave',
#               'Francesca Ave',
#               'Mystic Ave',
#               'Commonwealth Ave',
#               'Lexington Ave',
#               'Willow Ave',
#               'Washington Ave',
#               'Columbus Ave',
#               'Harrison Ave',
#               'Somerville Ave',
#               'Western Ave',
#               'Everett Ave',
#               'Massachusetts Ave; Mass Ave',
#               'Massachusetts Ave',
#               'College Ave',
#               "St. Paul's Ave",
#               'Sagamore Ave',
#               'Josephine Ave',
#               'Blue Hill Ave',
#               'Concord Ave',
#               'Boston Ave',
#               '738 Commonwealth Ave'],
#              'Ave.': ['Columbus Ave.',
#               'Somerville Ave.',
#               'Massachusetts Ave.',
#               'Brighton Ave.',
#               'Spaulding Ave.'],
#              'Avenue': ['Prichard Avenue',
#               'Saint James Avenue',
#               'Black Falcon Avenue',
#               'Savin Hill Avenue',
#               'Canton Avenue',
#               'New Rutherford Avenue',
#               'Putnam Avenue',
#               'Massachussetts Avenue',
#               'Blue Hill Avenue',
#               'Belgrade Avenue',
#               'Western Avenue',
#               'Humboldt Avenue',
#               'Mildred Avenue',
#               'Burnside Avenue',
#               'Sunnyside Avenue',
#               'Boston Avenue',
#               'Pond Avenue',
#               'Willow Avenue',
#               'Mystic Avenue',
#               'South Huntington Avenue',
#               'Roanoke Avenue',
#               'Benedict Avenue',
#               'Packard Avenue',
#               'Huntington Avenue',
#               'Gordon Avenue',
#               'Spring Avenue',
#               'Myrtle Avenue',
#               'Hyde Park Avenue',
#               'Clark Avenue',
#               'Broadway Avenue',
#               'Highland Avenue',
#               'Central Avenue',
#               'Harris Avenue',
#               'Rindge Avenue',
#               'Talbot Avenue',
#               'Sewall Avenue',
#               'Reservoir Avenue',
#               'Randolph Avenue',
#               'Concord Avenue',
#               'Dorchester Avenue',
#               'Eastern Avenue',
#               'Huron Avenue',
#               'Chestnut Hill Avenue',
#               'Florence Avenue',
#               'Washington Avenue',
#               'Spencer Avenue',
#               'Middlesex Avenue',
#               'Proctor Avenue',
#               'Wyllis Avenue',
#               'Talbot  Avenue',
#               'Crescent Avenue',
#               'Crest Avenue',
#               'Brighton Avenue',
#               'Sycamore Avenue',
#               'Robinwood Avenue',
#               'Drydock Avenue',
#               'Bates Avenue',
#               'Everett Avenue',
#               'Cottage Avenue',
#               'First Avenue',
#               'Summit Avenue',
#               'Old Colony Avenue',
#               'Winthrop Avenue',
#               'Montcalm Avenue',
#               'Neponset Avenue',
#               'Charles River Avenue',
#               'rindge Avenue',
#               'Columbus Avenue',
#               'E Elm Avenue',
#               'Massichusette Avenue',
#               'Quincy Avenue',
#               'Massachusetts Avenue',
#               'Metropolitan Avenue',
#               'Longwood Avenue',
#               'Atlantic Avenue',
#               'Grant Avenue',
#               'Harvard Avenue',
#               'Fisk Avenue',
#               'Harrison Avenue',
#               'Kensington Avenue',
#               'Somerville Avenue',
#               'Carolina Avenue',
#               'Lexington Avenue',
#               'Divinity Avenue',
#               'College Avenue',
#               'View South Avenue',
#               'Whittemore Avenue',
#               'Parker Hill Avenue',
#               'Brookline Avenue',
#               'Maple Avenue',
#               'Riverside Avenue',
#               'Commonwealth Avenue',
#               'Webster Avenue',
#               'Jefferson Avenue',
#               'Greenough Avenue',
#               'Seaverns Avenue',
#               'Northern Avenue',
#               'Nichols Avenue',
#               'Aberdeen Avenue',
#               'Notre Dame Avenue',
#               'somerville Avenue'],
#              'Boulevard': ['Fan Pier Boulevard',
#               'William T. Morrissey Boulevard',
#               'Seaport Boulevard',
#               'Grand Union Boulevard',
#               'Morrissey Boulevard',
#               'Edwin H. Land Boulevard'],
#              'Boylston': ['Boylston'],
#              'Broadway': ['East Broadway', 'Broadway', 'West Broadway'],
#              'Brook': ['Furnace Brook'],
#              'Building': ['South Market Building'],
#              'Cambrdige': ['Cambrdige'],
#              'Center': ['Cambridge Center',
#               'Financial Center',
#               'Channel Center'],
#              'Circle': ['Achorn Circle',
#               'Stein Circle',
#               'Norcross Circle',
#               'Edgewood Circle'],
#              'Corner': ['Webster Street, Coolidge Corner'],
#              'Court': ['Park Street Court',
#               'North Bennet Court',
#               'Blossom Court',
#               'Necco Court'],
#              'Ct': ['Kelley Ct'],
#              'Dartmouth': ['Dartmouth'],
#              'Dr': ['Harborside Dr'],
#              'Drive': ['Harbor Shore Drive',
#               'George P Hassett Drive',
#               'Quincy Shore Drive',
#               'Shipyard Drive',
#               'Tomahawk Drive',
#               'Liberty Drive',
#               'Shore Drive',
#               'Independence Drive',
#               'Harborside Drive',
#               "River's Edge Drive",
#               'Marina Park Drive',
#               'Park Drive',
#               'Memorial Drive',
#               'Beacon Heights Drive',
#               'Cambridgepark Drive',
#               'Crown Colony Drive',
#               'Revolution Drive',
#               'Circuit Drive',
#               'St Thomas More Drive',
#               'Bishop Allen Drive',
#               'HMS Essington Drive'],
#              'Driveway': ['Museum of Science Driveway'],
#              'Elm': ['Elm'],
#              'Ext': ['B Street Ext'],
#              'Fellsway': ['Fellsway'],
#              'Fenway': ['Fenway'],
#              'Floor': ['Boylston Street, 5th Floor'],
#              'Garage': ['Stillings Street Garage'],
#              'Greenway': ['East Boston Greenway'],
#              'H': ['H'],
#              'HIghway': ['American Legion HIghway'],
#              'Hall': ['Faneuil Hall'],
#              'Hampshire': ['Hampshire'],
#              'Highway': ['McGrath Highway',
#               'Providence Highway',
#               "Monsignor O'Brien Highway",
#               'American Legion Highway',
#               'Cummins Highway',
#               'Santilli Highway'],
#              'Holland': ['Holland'],
#              'Hwy': ["Monsignor O'Brien Hwy"],
#              'Jamaicaway': ['Jamaicaway'],
#              'LEVEL': ['LOMASNEY WAY, ROOF LEVEL'],
#              'Lafayette': ['Avenue De Lafayette'],
#              'Lane': ['Puddingstone Lane',
#               'Echo Lane',
#               'Day School Lane',
#               'Pond Lane',
#               'Starr Lane',
#               'Phillips Lane',
#               'Hampstead Lane',
#               'Park Lane',
#               'Seaport Lane'],
#              'Longwood': ['Longwood'],
#              'Mall': ['Cummington Mall'],
#              'Market': ['Faneuil Hall Market'],
#              'Newbury': ['Newbury'],
#              'Park': ['Austin Park',
#               'Acorn Park',
#               'Canal Park',
#               'Batterymarch Park',
#               'Agassiz Park',
#               'Malden Street Park',
#               'Exeter Park',
#               'Giles Park',
#               'Monument Park',
#               'Granton Park',
#               'Greenough Park',
#               'Newsome Park'],
#              'Parkway': ['Mystic Valley Parkway',
#               'Revere Beach Parkway',
#               'Alewife Brook Parkway',
#               'Hammond Pond Parkway',
#               'Thomas Burgin Parkway',
#               'Veterancs of Foreign Wars Parkway',
#               'VFW Parkway',
#               'Veterans Of Foreign Wars Parkway',
#               'West Roxbury Parkway'],
#              'Pasteur': ['Avenue Louis Pasteur'],
#              'Pkwy': ['Birmingham Pkwy'],
#              'Pl': ['Longfellow Pl'],
#              'Place': ['Legacy Place',
#               'Park Place',
#               'Hillside Place',
#               'Carolina Place',
#               'Boston Medical Center Place',
#               'Holyoke Place',
#               'Percy Place',
#               'Ashburton Place',
#               'Pleasant Place',
#               'Speare Place',
#               'Maple Place',
#               'Thomson Place',
#               'South Market Place',
#               'Drummond Place',
#               'Dartmouth Place',
#               'Emerson Place',
#               'Winter Place',
#               'Longfellow Place',
#               'Whittier Place',
#               'Storey Place',
#               'Regent Place',
#               'Jamaica Place',
#               'Eliot Place',
#               'Temple Place',
#               'Linden Place',
#               'Hancock Place',
#               'Joslin Place',
#               'International Place',
#               'Sacramento Place'],
#              'Plaza': ['Park Plaza',
#               'One Schroeder Plaza',
#               'Two Center Plaza'],
#              'Rd': ['Abby Rd',
#               'Oakland Rd',
#               'Soldiers Field Rd',
#               'Bristol Rd',
#               'Aberdeen Rd',
#               'Squanto Rd',
#               'Goodnough Rd',
#               'Rawson Rd'],
#              'Road': ['Edgerly Road',
#               'Gordon Road',
#               'Dolphin Road',
#               'Herrick Road',
#               'Unquity Road',
#               'Edge HIll Road',
#               'Soldiers Field Road',
#               'Outlook Road',
#               'Essex Road',
#               'Northshore Road',
#               'Trapelo Road',
#               'Bay State Road',
#               'Dana Road',
#               'University Road',
#               'Philbrick Road',
#               'Martha Road',
#               'Deaconess Road',
#               'Billings Road',
#               'Kilsyth Road',
#               'Cabot Road',
#               'Buckminster Road',
#               'Grovenor Road',
#               'Edge Hill Road',
#               'Beverly Road',
#               'Dunbarton Road',
#               'Cadbury Road',
#               'Kenton Road',
#               'Berwick Road',
#               'Allstate Road',
#               'Service Road',
#               'Brookley Road',
#               'Benton Road',
#               'Reservoir Road',
#               'Menotomy Road',
#               'Clark Road',
#               'Highfield Road',
#               'Solaris Road',
#               'Coolidge Hill Road',
#               'Great River Road',
#               'Eric Road',
#               'Monsignor Jacobbe Road',
#               'Oakland Road',
#               'Glencliff Road',
#               'Juniper Road',
#               'Rossmore Road',
#               'Meadow Road',
#               'Orkney Road',
#               'Boston Wharf Road',
#               'Murray Road',
#               'Vanness Road',
#               'Mystic View Road',
#               'Ryan Road',
#               'Lower Campus Road',
#               'Newport Road',
#               'Bristol Road',
#               'Matignon Road',
#               'Ellington Road',
#               'Fenwood Road',
#               'Ruskindale Road',
#               'Greylock Road',
#               'Heath Road',
#               'Hampstead Road',
#               'Terminal Road',
#               'Dearborn Road',
#               'Columbia Road',
#               'Dunster Road',
#               'Reedsdale Road',
#               'Agawam Road'],
#              'Row': ['Professors Row', 'Assembly Row', 'East India Row'],
#              'ST': ['Newton ST'],
#              'South': ['Charles Street South'],
#              'Sq.': ['1 Kendall Sq.'],
#              'Square': ['Davis Square',
#               'Bartlett Square',
#               'Kendall Square',
#               'Liberty Square',
#               'Faneuil Hall Square',
#               'Freedom Square',
#               'Union Square',
#               'Technology Square',
#               'Post Office Square',
#               'Tech Square',
#               'Winthrop Square',
#               'Church Street, Harvard Square',
#               'Thompson Square',
#               'Atwood Square',
#               'City Hall Square',
#               'Warren Square',
#               'Court Square',
#               'North Square',
#               'Peabody Square',
#               '61 Union Square'],
#              'St': ['Brentwood St',
#               'Medford St',
#               'Leighton St',
#               'Stewart St',
#               'Bagnal St',
#               'Ware St',
#               'Norfolk St',
#               'Cambridge St',
#               'Main St',
#               'Congress St',
#               'Court St',
#               'Kirkland St',
#               'Adams St',
#               'South Waverly St',
#               'Hampshire St',
#               'Duval St',
#               'Holton St',
#               'N Beacon St',
#               'Winter St',
#               'Bowdoin St',
#               'Charles St',
#               'Portsmouth St',
#               'Everett St',
#               'Broad St',
#               'Athol St',
#               'Litchfield St',
#               'George St',
#               'Antwerp St',
#               'Elm St',
#               'Lothrop St',
#               'Mt Auburn St',
#               'Arsenal St',
#               'Centre St',
#               'Grove St',
#               'Maverick St',
#               'Hammond St',
#               'Dane St',
#               'Cummington St',
#               'Waverly St',
#               'Winthrop St',
#               'Richardson St',
#               'Mackin St',
#               'Merrill St',
#               'Sea St'],
#              'St,': ['Walnut St,'],
#              'St.': ["Saint Mary's St.",
#               'Marshall St.',
#               'Prospect St.',
#               'Banks St.',
#               'Stuart St.',
#               'Albion St.',
#               'Centre St.',
#               'Boylston St.',
#               'Pearl St.',
#               'Main St.',
#               'Maverick St.',
#               'Elm St.',
#               'Tremont St.'],
#              'Street': ['South Street',
#               'Charles Street',
#               'Wendell Street',
#               'Ware Street',
#               'Coddington Street',
#               'Richardson Street',
#               'Sedgwick Street',
#               'High Street',
#               'McBride Street',
#               'Windsor Street',
#               'John Street',
#               'Thomas Street',
#               'Pinckney Street',
#               'Winnisimmet Street',
#               'Farnsworth Street',
#               'Holyoke Street',
#               'Burroughs Street',
#               'First Street',
#               'West Second Street',
#               'Central Street',
#               'Squantum Street',
#               'School Street',
#               'Wormwood Street',
#               'Parmenter Street',
#               'Renfrew Street',
#               'Blossom Street',
#               'Tyler Street',
#               'Cottage Street',
#               'Bedford Street',
#               'Linwood Street',
#               'Amory Street',
#               'Marlborough Street',
#               'Anson Street',
#               'Wareham Street',
#               'Wellington Street',
#               'Windom Street',
#               'Shattuck Street',
#               'Medford Street',
#               'Exeter Street',
#               'East Dedham Street',
#               'Causeway Street',
#               'Lansdowne Street',
#               'Alton Street',
#               'Clinton Street',
#               'Friend Street',
#               'Atherton Street',
#               'Morton Street',
#               'Jamaica Street',
#               'Ashford Street',
#               'Mount Auburn Street',
#               'Gardner Street',
#               'Third Street',
#               'Silk Street',
#               'Ibbetson Street',
#               'Bassett Street',
#               'Garland Street',
#               'Elm Street',
#               'Princeton Street',
#               'DeWolfe Street',
#               'Cambridge Street',
#               'Commercial Street',
#               'Hebron Street',
#               'North Harvard Street',
#               'Arsenal Street',
#               'Sunnyside Street',
#               'Bardwell Street',
#               'Hawes Street',
#               'Bellingham Street',
#               'Aldie Street',
#               'Shepard Street',
#               'Brentwood Street',
#               'Verona Street',
#               'Bent Street',
#               'Germania Street',
#               'Landsdowne Street',
#               'Harvard Street',
#               'Fremont Street',
#               'Boston Street',
#               'Lincoln Street',
#               'Brimmer Street',
#               'Jeffries Street',
#               'Thacher Street',
#               'Beach Street',
#               'Trowbridge Street',
#               'Adams Street',
#               'Walnut Street',
#               'James Street',
#               'Circuit Street',
#               'Mansfield Street',
#               'Aldersey Street',
#               'Alberta Street',
#               'Paul Gore Street',
#               'Linden Street',
#               'Norris Street',
#               'Endicott Street',
#               'Hall Street',
#               'Columbia Street',
#               'Gore Street',
#               'Dalton Street',
#               'Alveston Street',
#               'Dartmouth Street',
#               'Locust Street',
#               'South Market Street',
#               'Plainfield Street',
#               'Travis Street',
#               'Irving Street',
#               'River Street',
#               'Merrimac Street',
#               'Staniford Street',
#               'Orchard Street',
#               'Fayette Street',
#               'Canterbury Street',
#               'Warrenton Street',
#               'Beechcroft Street',
#               'Jay Street',
#               'Julia Street',
#               'Dresden Street',
#               'North Market Street',
#               'Beale Street',
#               'Warren Street',
#               'Darthmouth Street',
#               'Malden Street',
#               'Prescott Street',
#               'Myrtle Street',
#               'State Street',
#               'Province Street',
#               'Water Street',
#               'Pemberton Street',
#               'Fawcett Street',
#               'Mount Vernon Street',
#               'New Washington Street',
#               'Benedict Street',
#               'Hanover Street',
#               'Otis Street',
#               'East Newton Street',
#               'Chandler Street',
#               'South Fairview Street',
#               'Newhall Street',
#               'Hull Street',
#               'Norfolk Street',
#               'Marrigan Street',
#               'Call Street',
#               'Colbert Street',
#               'Tremont Street',
#               'mount Auburn Street',
#               'Essex Street',
#               'Gorham Street',
#               'Marion Street',
#               'Vassar Street',
#               'Elmira Street',
#               'Melcher Street',
#               'Emily Street',
#               'Ridgemont Street',
#               'Granite Street',
#               'Walk Hill Street',
#               'Hathaway Street',
#               'Colchester Street',
#               'Oakland Street',
#               'Leon Street',
#               'Education Street',
#               'Canal Street',
#               'Palmer Street',
#               'Carleton Street',
#               'Sumner Street',
#               'D Street',
#               'Brewer Street',
#               'Parker Street',
#               'Vinal Street',
#               'Cushing Street',
#               'Washington Street',
#               'Child Street',
#               'Clark Street',
#               'Vernon Street',
#               'Dedham Street',
#               'Chauncy Street',
#               'Crescent Street',
#               'E Street',
#               'Yorktown Street',
#               'A Street',
#               'Holland Street',
#               'Walbridge Street',
#               'Wilton Street',
#               'Pearl Street',
#               'Dunster Street',
#               'Ericsson Street',
#               'Upton Street',
#               'Congress Street',
#               'Portland Street',
#               'Hilton Street',
#               'Salem Street',
#               'Iroquois Street',
#               'Belmont Street',
#               'Plympton Street',
#               'Howard Street',
#               'Brookline Street',
#               'Wadsworth Street',
#               'Bickford Street',
#               'Newbern Street',
#               'Bussey Street',
#               'Laurel Street',
#               'Gordon Street',
#               'Bond Street',
#               'West Street',
#               'Porter Street',
#               'Hagar Street',
#               'Wyman Street',
#               'Sea Street',
#               'Piedmont Street',
#               'Bowlston Street',
#               'Oxford Street',
#               'Bay Street',
#               'Green Street',
#               'Emerson Street',
#               'Necco Street',
#               'Cummings Street',
#               'Beech Street',
#               'Cowperthwaite Street',
#               'Blackstone Street',
#               'Arlington Street',
#               'Boylston Street',
#               'Quincy Street',
#               'Clyde Street',
#               'Clarendon Street',
#               'North Bennet Street',
#               'harvard Street',
#               'Sherman Street',
#               'Tudor Street',
#               'Edinboro Street',
#               'Kingston Street',
#               'Terminal Street',
#               'Saint Alphonsus Street',
#               'Lowell Street',
#               'Cherry Street',
#               'North Washington Street',
#               'Pitman Street',
#               'Calumet Street',
#               'Ames Street',
#               'Round Hill Street',
#               'Albany Street',
#               'Sheridan Street',
#               'Second Street',
#               'East Street',
#               'Broad Canal Street',
#               'Allen Street',
#               'Rosecliff Street',
#               'Hawthorn Street',
#               'Heath Street',
#               'Summer Street',
#               'Faneuil Street',
#               'Watertown Street',
#               'Penn Street',
#               'Michael Street',
#               'Clary Street',
#               'Carver Street',
#               'Bishop Street',
#               'Regent Street',
#               'East Concord Street',
#               'Maxfield Street',
#               'Devir Street',
#               'Hampshire Street',
#               'Lexington Street',
#               'P Street',
#               'Dudley Street',
#               'Milton Street',
#               'Saint Mark Street',
#               'Lake Street',
#               'Agassiz Street',
#               'Etna Street',
#               'Loomis Street',
#               'Traveler Street',
#               'White Street',
#               'Winter Street',
#               'Custer Street',
#               'Alcott Street',
#               'Bridge Street',
#               'Spalding Street',
#               'Auburn Street',
#               'Aldworth Street',
#               'Nonantum Street',
#               'Kirkland Street',
#               'Magazine Street',
#               'Harrison Street',
#               'Washburn Street',
#               'Sidney Street',
#               'Guest Street',
#               'Norcross Street',
#               'John F. Kennedy Street',
#               'San Juan Street',
#               'Williams Street',
#               'Saint Joseph Street',
#               'Avon Street',
#               'Bromfield Street',
#               'Somerset Street',
#               'Eatonia Street',
#               'Stuart Street',
#               'Babcock Street',
#               'Main Street',
#               'Saint Marys Street',
#               'Roxbury Street',
#               'Everett Street',
#               'Chester Street',
#               'Boynton Street',
#               'Alfred Street',
#               'Remington Street',
#               'Mellen Street',
#               'Draper Street',
#               'Murdock Street',
#               'Belvidere Street',
#               'Meridian Street',
#               'Bowker Street',
#               'Saint Paul Street',
#               'Bennington Street',
#               'Binney Street',
#               'North Beacon Street',
#               'Arch Street',
#               'Grove Street',
#               'Wentworth Street',
#               'L Street',
#               'Prospect Street',
#               'Montgomery Street',
#               'Forsyth Street',
#               'Brighton Street',
#               'East Second Street',
#               'Holbrook Street',
#               'Sacramento Street',
#               'Akron Street',
#               'Mason Street',
#               'Kendall Street',
#               'Peverell Street',
#               'Temple Street',
#               'Whitwell Street',
#               'Saint Rose Street',
#               'Austin Street',
#               'Batterymarch Street',
#               'Danforth Street',
#               'Chestnut Street',
#               'Kelvin Street',
#               'Park Street',
#               'Aramon Street',
#               'Intervale Street',
#               'Cross Street',
#               'Nashua Street',
#               'Federal Street',
#               'Ballard Street',
#               'Newbury Street',
#               'Maverick Street',
#               'Webster Street',
#               'Amherst Street',
#               'Buick Street',
#               'Poplar Street',
#               'Garden Street',
#               'Tide Street',
#               'Adamson Street',
#               'William Street',
#               'East Berkeley Street',
#               'Eliot Street',
#               'Milk Street',
#               'East Springfield Street',
#               'Addison Street',
#               'Oliver Street',
#               'Gibson Street',
#               'Lagrange Street',
#               'Marginal Street',
#               'Market Street',
#               'Broad Street',
#               'Hudson Street',
#               'Devereaux Street',
#               'Brattle Street',
#               'Curtis Street',
#               'Dorchester Street',
#               'Holton Street',
#               'Saint Stepen Street',
#               'Chelsea Street',
#               'Foster Street',
#               'Franklin Street',
#               'Berkeley Street',
#               '3rd Street',
#               'West Kendall Street',
#               'Woodman Street',
#               'Kneeland Street',
#               'Vine Street',
#               'Norman Street',
#               'Martin Street',
#               'Marshall Street',
#               'Ipswich Street',
#               'Baker Street',
#               'East Fourth Street',
#               'Cedar Street',
#               'Corey Street',
#               'Linnaean Street',
#               'Harris Street',
#               'John A Andrew Street',
#               'Hemenway Street',
#               'East Kendall Street',
#               'Dustin Street',
#               'Mill Street',
#               'Heard Street',
#               'Revere Street',
#               'Saint Stephens Street',
#               'Inman Street',
#               'Hillside Street',
#               'Day Street',
#               'Winthrop Street',
#               'Colerain Street',
#               'Bow Street',
#               'Devonshire Street',
#               'Kilmarnock Street',
#               'Arrow Street',
#               'Gove Street',
#               'Avery Street',
#               'Hammond Street',
#               'Sydney Street',
#               'Sleeper Street',
#               'Moulton Street',
#               'Pleasant Street',
#               'Winslow Street',
#               'Kenrick Street',
#               'Pierce Street',
#               'Rosemary Street',
#               'Nichols Street',
#               'Albion Street',
#               'Dane Street',
#               'Moore Street',
#               'Beacon Street',
#               'Glencoe Street',
#               'Church Street',
#               'Chauncey Street',
#               'North Street',
#               'Centre Street',
#               'Back Street',
#               'Perkins Street',
#               'Hancock Street',
#               'West School Street',
#               'East Canton Street',
#               'Armstrong Street',
#               'Common Street',
#               'Lee Street',
#               'Kinnaird Street',
#               'Armington Street',
#               'Cypress Street',
#               'North Union Street',
#               'Erie Street',
#               'Ashley Street',
#               'Spring Street',
#               'Allston Street',
#               'Prince Street',
#               'Goldsmith Street',
#               'Union Street',
#               'Fruit Street',
#               '5th Street',
#               'Pond Street',
#               'Alpine Street',
#               'Francis Street'],
#              'Street.': ['Hancock Street.'],
#              'Terrace': ['Hillside Terrace',
#               'Beecher Terrace',
#               'Westbourne Terrace',
#               'Alveston Terrace',
#               'Norfolk Terrace',
#               'Alberta Terrace',
#               'Oakview Terrace',
#               'Arborway Terrace'],
#              'Turnpike': ['Boston Providence Turnpike'],
#              'Way': ['Riley Way',
#               'Courthouse Way',
#               'David G Mugar Way',
#               'Harry Agganis Way',
#               'Davidson Way',
#               'Transportation Way',
#               'Ballard Way',
#               'Artisan Way',
#               'Memorial Way',
#               'Yawkey Way',
#               "Commandant's Way",
#               'Ross Way',
#               'Cedar Lane Way',
#               'Legends Way',
#               'Evans Way'],
#              'Wharf': ['Long Wharf',
#               'Central Wharf',
#               'Lewis Wharf',
#               'Rowes Wharf'],
#              'Windsor': ['Windsor'],
#              'Winsor': ['Winsor'],
#              'Yard': ['Charleston Navy Yard'],
#              'floor': ['Sidney Street, 2nd floor', 'First Street, 18th floor'],
#              'place': ['argus place'],
#              'rd.': ['Corey rd.'],
#              'st': ['Main st'],
#              'street': ['Boston street']})

# %% [markdown]
# ===> key值```addr:street```的value值需要进行修正。

# %% [markdown]
# #### ‘tag'标记属性修正方案
# + 按```key_mapping```修正key值
# + 分别按```state_mapping```、 ```street_mapping```修正"addr:state'和'addr:street'

# %%
key_mapping = {"(new tag)": "new_tag",
               "service area": "service_area",
               "addr:street_1": "addr:street"}

state_mapping = {'ma': 'MA',
                 'MA- MASSACHUSETTS' : 'MA',
                 'Ma' : 'MA',
                 'Massachusetts' : 'MA'}

street_mapping = { "St": "Street",
                    "St.": "Street",
                    "ST" : "Street",
                    "St" : "Street",
                    "St," : "Street",
                    "st" : "Street",
                    "street": "Street",
                    "Street." : "Street",
                    "Rd" : "Road",
                    "Rd.": "Road",
                    "rd.": "Road",
                    "Ave": "Avenue",
                    "Ave.":"Avenue",
                    "HIghway": "Highway",
                    "Pkwy" : "Parkway",
                    "Sq." : "Square",
                    "Winsor": "Winsor",
                     }

# %% [markdown]
# ### 将数据修正后写入CSV文件

# %%
# 修正key值
def correct_key(key):
    if key in key_mapping.keys():
        key = key_mapping[key]
    return key  

# 修正value值
def correct_value(key, value):
    
    if key == 'addr:state':
        if value in state_mapping.keys():
            value = state_mapping[value]
            
    if key == 'addr:street':
        abbr = value.split(" ")[-1] 
        if abbr in street_mapping.keys():
            value = value.replace(abbr, street_mapping[abbr]) 
            
    return value

# 修正type值    
def shape_tag(key):
    if LOWER_COLON.search(key):
        colon_pos = key.index(":")
        k = key[colon_pos+1 :]
        t = key[: colon_pos]
    else:
        k = key
        t = 'regular'
    return k, t   
                
# 修正根元素root    
def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements

    if element.tag == 'node':
        
        # "node"
        for tag in node_attr_fields:  
            node_attribs[tag] = element.attrib[tag]        
        
        for subelem in element:
            
            # "node_tags"
            if subelem.tag == 'tag':
                
                k = correct_key(subelem.attrib['k'])
                v = correct_value(k, subelem.attrib['v'])
                
                entry = {}
                entry['id'] = element.attrib['id']
                entry['key'], entry['type'] = shape_tag(k)              
                entry['value'] = v
                
                tags.append(entry)
       
        return {'node': node_attribs, 'node_tags': tags}
    
    elif element.tag == 'way':
        
        # "way"
        for tag in way_attr_fields:
            way_attribs[tag] = element.attrib[tag] 
            
        count = 0    
        for subelem in element:
            
            # "way_tags"
            if subelem.tag == 'tag':
              
                k = correct_key(subelem.attrib['k'])
                v = correct_value(k, subelem.attrib['v'])
                
                entry = {}
                entry['id'] = element.attrib['id']
                entry['key'], entry['type'] = shape_tag(k)              
                entry['value'] = v
                
                tags.append(entry)
            
            # "way_nodes"
            if subelem.tag == 'nd':
                entry = {}
                entry['id'] = element.attrib['id']
                entry['node_id'] = subelem.attrib['ref']
                entry['position'] = count
                count += 1 
                way_nodes.append(entry)           
        
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

# %%
# ================================================== #
#               Helper Functions                     #
# ================================================== #
# 依次获取根元素
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)
       

 # ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])

# Note: Validation is ~ 10X slower. For the project consider using a small
# sample of the map when validating.

# %%
# 处理sample文件并验证
NODES_PATH = "sample_nodes.csv"
NODE_TAGS_PATH = "sample_nodes_tags.csv"
WAYS_PATH = "sample_ways.csv"
WAY_NODES_PATH = "sample_ways_nodes.csv"
WAY_TAGS_PATH = "sample_ways_tags.csv"

process_map(SAMPLE_FILE, validate=True)

# %%
# 处理osm文件
NODES_PATH = "csv/nodes.csv"
NODE_TAGS_PATH = "csv/nodes_tags.csv"
WAYS_PATH = "csv/ways.csv"
WAY_NODES_PATH = "csv/ways_nodes.csv"
WAY_TAGS_PATH = "csv/ways_tags.csv"

process_map(OSM_FILE, validate=False)

# %% [markdown]
# ### 将CSV文件导入数据库中

# %% [markdown]
# 创建数据库，修改分隔符。
# ```sql
# PS ***> sqlite3 BostonOSM.db
# SQLite version 3.9.2 2015-11-02 18:31:45
# Enter ".help" for usage hints.
# sqlite> .show
#         echo: off
#          eqp: off
#   explain: off
#      headers: off
#         mode: list
#    nullvalue: ""
#       output: stdout
# colseparator: "|"
# rowseparator: "\n"
#        stats: off
#        width:
# sqlite> .separator ","
# sqlite> .show
#         echo: off
#          eqp: off
#   explain: off
#      headers: off
#         mode: list
#    nullvalue: ""
#       output: stdout
# colseparator: ","
# rowseparator: "\n"
#        stats: off
#        width:
# ```
# 创建表格并查看：
# ```sql
# sqlite> CREATE TABLE nodes (
#    ...>     id INTEGER PRIMARY KEY NOT NULL,
#    ...>     lat REAL,
#    ...>     lon REAL,
#    ...>     user TEXT,
#    ...>     uid INTEGER,
#    ...>     version INTEGER,
#    ...>     changeset INTEGER,
#    ...>     timestamp TEXT
#    ...> );
# sqlite>
# sqlite> CREATE TABLE nodes_tags (
#    ...>     id INTEGER,
#    ...>     key TEXT,
#    ...>     value TEXT,
#    ...>     type TEXT,
#    ...>     FOREIGN KEY (id) REFERENCES nodes(id)
#    ...> );
# sqlite>
# sqlite> CREATE TABLE ways (
#    ...>     id INTEGER PRIMARY KEY NOT NULL,
#    ...>     user TEXT,
#    ...>     uid INTEGER,
#    ...>     version TEXT,
#    ...>     changeset INTEGER,
#    ...>     timestamp TEXT
#    ...> );
# sqlite>
# sqlite> CREATE TABLE ways_tags (
#    ...>     id INTEGER NOT NULL,
#    ...>     key TEXT NOT NULL,
#    ...>     value TEXT NOT NULL,
#    ...>     type TEXT,
#    ...>     FOREIGN KEY (id) REFERENCES ways(id)
#    ...> );
# sqlite>
# sqlite> CREATE TABLE ways_nodes (
#    ...>     id INTEGER NOT NULL,
#    ...>     node_id INTEGER NOT NULL,
#    ...>     position INTEGER NOT NULL,
#    ...>     FOREIGN KEY (id) REFERENCES ways(id),
#    ...>     FOREIGN KEY (node_id) REFERENCES nodes(id)
#    ...> );
# sqlite> .tables
# nodes       nodes_tags  ways        ways_nodes  ways_tags
# ```
# 导入csv文件，出现错误```INSERT failed: datatype mismatch```，我查看了nodes前5行数据，并没发现异常之处。参考论坛帖子发现第一行mismatch应该是由于csv header全为字符串，与schema不符导致报错，不会影响数据导入和查询。
# ```sql
# sqlite> .import nodes.csv nodes
# nodes.csv:1: INSERT failed: datatype mismatch
# sqlite> SELECT * FROM nodes LIMIT 5;
# 30730952,42.3678097,-71.0218711,wambag,326503,2,14335103,2012-12-19T19:24:31Z
# 30730953,42.3677364,-71.0218568,wambag,326503,2,14335103,2012-12-19T19:24:31Z
# 30730954,42.3676084,-71.0218168,wambag,326503,2,14335103,2012-12-19T19:24:31Z
# 30730955,42.3675229,-71.0218486,wambag,326503,2,14335103,2012-12-19T19:24:32Z
# 30730956,42.3674548,-71.0218865,wambag,326503,2,14335103,2012-12-19T19:24:31Z
# sqlite> .import nodes_tags.csv nodes_tags
# sqlite> .import ways.csv ways
# ways.csv:1: INSERT failed: datatype mismatch
# sqlite> .import ways_tags.csv ways_tags
# sqlite> .import ways_nodes.csv ways_nodes
# ```
